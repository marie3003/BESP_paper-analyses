# %% [markdown]
# # Evaluate subsampling validity
# Test whether subsampling to 1000 posterior samples instead of choosing the full 27000 samples impact the results majorly

# %%
from Bio import Nexus, Phylo, SeqIO
from collections import defaultdict
from io import StringIO

import matplotlib.pyplot as plt
from matplotlib import gridspec

import seaborn as sns

import pandas as pd
import numpy as np

import re
from pathlib import Path

from itertools import combinations

from evaluation_helpers import *

# %%
tree_metrics_combined_1000 = load_node_errors("../results/run1/evaluation")
tree_metrics_combined_27000 = load_node_errors("../results/run1/single_tree_full_chain_test")
# Out:
# /Users/mariebecker/Documents/Uni/ETH/RotationStadler/BESP_paper-analyses/workflows/evaluation_helpers.py:4063: DtypeWarning: Columns (50,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(tsv, sep="\t"))
# /Users/mariebecker/Documents/Uni/ETH/RotationStadler/BESP_paper-analyses/workflows/evaluation_helpers.py:4063: DtypeWarning: Columns (50,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(tsv, sep="\t"))
# /Users/mariebecker/Documents/Uni/ETH/RotationStadler/BESP_paper-analyses/workflows/evaluation_helpers.py:4063: DtypeWarning: Columns (50,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(tsv, sep="\t"))
# /Users/mariebecker/Documents/Uni/ETH/RotationStadler/BESP_paper-analyses/workflows/evaluation_helpers.py:4063: DtypeWarning: Columns (50,94) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
plot_full_vs_subsampled_median_hpd(
    df_sub = tree_metrics_combined_1000, df_full = tree_metrics_combined_27000,
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",
    error_col="bl_est",
)

plot_full_vs_subsampled_median_hpd(
    df_sub = tree_metrics_combined_1000, df_full = tree_metrics_combined_27000,
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",
    error_col="bl_rel_error",
)

# %%
plot_full_vs_subsampled_popsize_median_hpd(
    sub_eval_dir="../results/run1/evaluation",
    full_eval_dir="../results/run1/single_tree_full_chain_test",
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",
)

# %%
# median comparison, branch-length relative error                                                                                                                    
plot_full_vs_subsampled_grid(
    df_sub = tree_metrics_combined_1000, df_full = tree_metrics_combined_27000,
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",                                                                                                        
    error_col="bl_rel_error",
    mode="median",
)
                                                                                                                                                                                
# HPD width comparison, same metric                                                                                                                                                        
plot_full_vs_subsampled_grid(
    df_sub = tree_metrics_combined_1000, df_full = tree_metrics_combined_27000,
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",
    error_col="bl_rel_error",
    mode="hpd_width",                                                                                                                                                                                                                                                                                                                              
)

# %%
tree_metrics_combined_27000.columns
# Out:
# Index(['tree_index', 'node_idx', 'node_id', 'internal', 'height_sim', 'bl_sim',
#        'constcoal_pop_diff_median', 'constcoal_pop_diff_hpd_lower',
#        'constcoal_pop_diff_hpd_upper', 'constcoal_pop_rel_error_median',
#        'constcoal_pop_rel_error_hpd_lower',
#        'constcoal_pop_rel_error_hpd_upper',
#        'constcoal_pop_abs_rel_error_median',
#        'constcoal_pop_abs_rel_error_hpd_lower',
#        'constcoal_pop_abs_rel_error_hpd_upper', 'constcoal_rate_diff_median',
#        'constcoal_rate_diff_hpd_lower', 'constcoal_rate_diff_hpd_upper',
#        'constcoal_rate_rel_error_median', 'constcoal_rate_rel_error_hpd_lower',
#        'constcoal_rate_rel_error_hpd_upper',
#        'constcoal_rate_abs_rel_error_median',
#        'constcoal_rate_abs_rel_error_hpd_lower',
#        'constcoal_rate_abs_rel_error_hpd_upper',
#        'constcoal_height_diff_median', 'constcoal_height_diff_hpd_lower',
# ...

# %%
# median comparison, population size                                                                                                                   
plot_full_vs_subsampled_grid(
    df_sub = tree_metrics_combined_1000, df_full = tree_metrics_combined_27000,
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",                                                                                                        
    error_col="rate_rel_error",
    mode="median",
)
                                                                                                                                                                                
# HPD width comparison, same metric                                                                                                                                                        
plot_full_vs_subsampled_grid(
    df_sub = tree_metrics_combined_1000, df_full = tree_metrics_combined_27000,
    job_stats="../results/run1/single_tree_full_chain_test/job_stats.tsv",
    error_col="rate_rel_error",
    mode="hpd_width",
)
